# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-2-d5df0069828e> in <module>
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms)
#     103       force_remount=force_remount,
#     104       timeout_ms=timeout_ms,
# --> 105       ephemeral=True)
#     106
#     107
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral)
#     118   if ephemeral:
#     119     _message.blocking_request(
# --> 120         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     121
#     122   mountpoint = _os.path.expanduser(mountpoint)
#
# ...

# %%
import os

# %%
path='/content/drive/MyDrive/Yolo'
print(os.listdir(path))
# Out:
# ['yolov4', 'Myyolo', 'Yolov4_obj_detect.ipynb', 'plant_detection.ipynb']

# %%
os.chdir('/content/drive/MyDrive/Yolo')

# %%
# Cloning the darknet repo
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15490, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 15490 (delta 10), reused 23 (delta 9), pack-reused 15460
# Receiving objects: 100% (15490/15490), 14.10 MiB | 7.89 MiB/s, done.
# Resolving deltas: 100% (10395/10395), done.
# Checking out files: 100% (2057/2057), done.

# %%
# !ls
# Out:
# darknet  Myyolo  plant_detection.ipynb	yolov4	Yolov4_obj_detect.ipynb

# %%
# %cd darknet/
# Out:
# /content/drive/MyDrive/Yolo/darknet

# %%
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/g' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/g' Makefile
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
os.chdir('/content/drive/MyDrive/Yolo/darknet')

# %%
# !cp cfg/yolov4-tiny.cfg cfg/mymodelcfg.cfg

# %%
try:
  os.mkdir('/content/drive/MyDrive/Yolo/weight')
except:
  pass

# %%
# !ls
# Out:
# darknet  Myyolo  plant_detection.ipynb	weight	yolov4	Yolov4_obj_detect.ipynb

# %%
# !make
# Out:
# chmod +x *.sh

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	json_mjpeg_streams.sh  scripts
# backup		darknet_images.py	LICENSE		       src
# build		darknet.py		Makefile	       vcpkg.json
# build.ps1	darknet_video.py	net_cam_v3.sh	       video_yolov3.sh
# cfg		data			net_cam_v4.sh	       video_yolov4.sh
# cmake		image_yolov3.sh		obj
# CMakeLists.txt	image_yolov4.sh		README.md
# darknet		include			results

# %%
os.chdir('/content/drive/MyDrive/Yolo/darknet')

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	json_mjpeg_streams.sh  scripts
# backup		darknet_images.py	LICENSE		       src
# build		darknet.py		Makefile	       vcpkg.json
# build.ps1	darknet_video.py	net_cam_v3.sh	       video_yolov3.sh
# cfg		data			net_cam_v4.sh	       video_yolov4.sh
# cmake		image_yolov3.sh		obj
# CMakeLists.txt	image_yolov4.sh		README.md
# darknet		include			results

# %%
 # !unzip /content/drive/MyDrive/Yolo/Dataset.zip -d /content/drive/MyDrive/MyYolo/custom_dat
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/MyYolo/Dataset.zip, /content/drive/MyDrive/MyYolo/Dataset.zip.zip or /content/drive/MyDrive/MyYolo/Dataset.zip.ZIP.

# %%
# !echo $'Plant' > data/obj.names

# !echo -e 'classes= 1\ntrain = data/train.txt\nvalid = data/test.txt\nnames = data/obj.names\nbackup = /content/drive/MyDrive/Yolo/weight/' > data/obj.data

# %%
os.chdir('/content/drive/MyDrive/Yolo/darknet')

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	json_mjpeg_streams.sh  scripts
# backup		darknet_images.py	LICENSE		       src
# build		darknet.py		Makefile	       vcpkg.json
# build.ps1	darknet_video.py	net_cam_v3.sh	       video_yolov3.sh
# cfg		data			net_cam_v4.sh	       video_yolov4.sh
# cmake		image_yolov3.sh		obj
# CMakeLists.txt	image_yolov4.sh		README.md
# darknet		include			results

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2022-08-30 06:12:59--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  16.1MB/s    in 11s
#
# 2022-08-30 06:13:11 (14.1 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !ls
# Out:
# 3rdparty	darknet53.conv.74	include		       results
# backup		DarknetConfig.cmake.in	json_mjpeg_streams.sh  scripts
# build		darknet_images.py	LICENSE		       src
# build.ps1	darknet.py		Makefile	       vcpkg.json
# cfg		darknet_video.py	net_cam_v3.sh	       video_yolov3.sh
# cmake		data			net_cam_v4.sh	       video_yolov4.sh
# CMakeLists.txt	image_yolov3.sh		obj
# darknet		image_yolov4.sh		README.md

# %%
os.chdir('/content/drive/MyDrive/Yolo/darknet')

# %%
 # !cp -r /content/drive/MyDrive/Yolo/Myyolo/train -d data/obj

# %%
 # !cp -r /content/drive/MyDrive/Yolo/Myyolo/test -d data/obj

# %%
import glob
image_list=glob.glob("data/obj/train/*.jpg")
print(image_list)
# Out:
# ['data/obj/train/1.jpg', 'data/obj/train/2.jpg', 'data/obj/train/3.jpg', 'data/obj/train/4.jpg', 'data/obj/train/5.jpg', 'data/obj/train/6.jpg', 'data/obj/train/7.jpg', 'data/obj/train/8.jpg', 'data/obj/train/9.jpg', 'data/obj/train/10.jpg', 'data/obj/train/11.jpg', 'data/obj/train/12.jpg', 'data/obj/train/14.jpg', 'data/obj/train/13.jpg', 'data/obj/train/16.jpg', 'data/obj/train/15.jpg', 'data/obj/train/17.jpg', 'data/obj/train/18.jpg', 'data/obj/train/19.jpg', 'data/obj/train/20.jpg', 'data/obj/train/21.jpg', 'data/obj/train/22.jpg', 'data/obj/train/26.jpg', 'data/obj/train/24.jpg', 'data/obj/train/23.jpg', 'data/obj/train/25.jpg', 'data/obj/train/27.jpg', 'data/obj/train/28.jpg', 'data/obj/train/29.jpg', 'data/obj/train/30.jpg', 'data/obj/train/33.jpg', 'data/obj/train/32.jpg', 'data/obj/train/31.jpg', 'data/obj/train/34.jpg', 'data/obj/train/35.jpg', 'data/obj/train/36.jpg', 'data/obj/train/37.jpg', 'data/obj/train/38.jpg', 'data/obj/train/39.jpg', 'data/obj/train/40.jpg']

# %%
file=open("data/train.txt","w")
file.write("\n".join(image_list))
file.close()

# %%
image_list=glob.glob("data/obj/test/*.jpg")
print(image_list)
# Out:
# ['data/obj/test/41.jpg', 'data/obj/test/42.jpg', 'data/obj/test/44.jpg', 'data/obj/test/43.jpg', 'data/obj/test/45.jpg', 'data/obj/test/46.jpg', 'data/obj/test/47.jpg', 'data/obj/test/48.jpg']

# %%
file=open("data/test.txt","w")
file.write("\n".join(image_list))
file.close()

# %%
# !./darknet detector train data//obj.data cfg/mymodelcfg.cfg darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.590758), count: 2, class_loss = 0.748206, iou_loss = 0.693426, total_loss = 1.441633
#  total_bbox = 87003, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.725510), count: 1, class_loss = 0.404858, iou_loss = 0.414257, total_loss = 0.819115
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.693603), count: 2, class_loss = 0.872676, iou_loss = 0.960553, total_loss = 1.833229
#  total_bbox = 87006, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.632718), count: 2, class_loss = 0.697310, iou_loss = 0.240093, total_loss = 0.937403
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.581714), count: 1, class_loss = 0.335060, iou_loss = 0.115281, total_loss = 0.450341
# ...

# %%
# !./darknet detector train data//obj.data cfg/mymodelcfg.cfg /content/drive/MyDrive/Yolo/weight/mymodelcfg_last.weights -dont_show
# Out:
# /bin/bash: ./darknet: No such file or directory

# %%
# !./darknet detector test data//obj.data cfg/mymodelcfg.cfg /content/drive/MyDrive/Yolo/weight/mymodelcfg_last.weights data/obj/test/41.jpg -dont_show
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 32, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
#    7 conv     64       1 x 1/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.089 BF
# ...

# %%
# Helper function for running displaying detections on colab
def imshow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

imshow('predictions.jpg')

# %%
# !./darknet detector train data//obj.data cfg/mymodelcfg.cfg darknet53.conv.74 -dont_show

# %%
# !./darknet detector demo train data//obj.data cfg/mymodelcfg.cfg /content/drive/MyDrive/Yolo/weight/mymodelcfg_last.weights -dont_show /content/drive/MyDrive/Yolo/test.mp4  -i 0 -out_filename /content/drive/MyDrive/Yolo/output.avi
